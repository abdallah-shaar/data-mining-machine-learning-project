# %%
# %run project(code).py
# Out:
# Dataset: heart.csv
# Number of rows: 1025
# Number of class 0: 499
# Number of class 1: 526
# Number of features: 13
# Training samples: 717
# Testing samples: 308
# ====== Decision Tree ======
# Accuracy:
# 0.9903
#
# Macro Accuracy:
# 0.9898
#
# Macro Precision, Recall, F1:
# P=0.9909  R=0.9898  F1=0.9902
#
# ====== Confusion Matrix (Counts) ======
# [[161   0]
#  [  3 144]]
#
# ====== Confusion Matrix (Normalized) ======
# [[1.   0.  ]
#  [0.02 0.98]]
#
# ====== Classification Report ======
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99       161
#          1.0       1.00      0.98      0.99       147
#
#     accuracy                           0.99       308
#    macro avg       0.99      0.99      0.99       308
# weighted avg       0.99      0.99      0.99       308
# ====== Decision Tree: Impact of max_depth ======
# Depth: 1 Acc: 0.7727 MacroAcc: 0.7737 MacroF1: 0.7727
# ...
